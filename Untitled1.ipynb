# %%
pip install yfinance
# Out:
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# ...
#   Created wheel for peewee: filename=peewee-3.16.3-py3-none-any.whl size=135547 sha256=4171920f26a6d3bf53c0c2e4ec517afd8970a4a806ee83b1433c4e87fa935be6
#   Stored in directory: c:\users\jucille escala\appdata\local\pip\cache\wheels\c8\ac\6d\ad6d828725ffbe3abc508c95d25dd0c5fcc63539ae47913790
# Successfully built peewee
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.28.2
#     Uninstalling requests-2.28.2:
#       Successfully uninstalled requests-2.28.2
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.3; however, version 23.2.1 is available.
# ...

# %%
import yfinance as yf

pfe = yf.Ticker('PFE')
pfe.info
# Out:
# {'address1': '66 Hudson Boulevard East',
#  'city': 'New York',
#  'state': 'NY',
#  'zip': '10001-2192',
#  'country': 'United States',
#  'phone': '212 733 2323',
#  'website': 'https://www.pfizer.com',
#  'industry': 'Drug Manufacturers—General',
#  'industryDisp': 'Drug Manufacturers—General',
#  'sector': 'Healthcare',
#  'sectorDisp': 'Healthcare',
# ...

# %%
pfe.actions
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\peewee.py:3192, in Database.connect(self, reuse_if_open)
#    3191 with __exception_wrapper__:
# -> 3192     self._state.set_connection(self._connect())
#    3193     if self.server_version is None:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\peewee.py:3536, in SqliteDatabase._connect(self)
#    3535     raise ImproperlyConfigured('SQLite driver not installed!')
# -> 3536 conn = sqlite3.connect(self.database, timeout=self._timeout,
#    3537                        isolation_level=None, **self.connect_params)
#    3538 try:
#
# OperationalError: unable to open database file
#
# During handling of the above exception, another exception occurred:
#
# OperationalError                          Traceback (most recent call last)
# ...
